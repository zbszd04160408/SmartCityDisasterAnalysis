# %%
import pandas as pd
import numpy as np
import re

# %%
twitter_df = pd.read_csv("./data/twitter_content.csv", index_col=0)
twitter_df
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-09-03 23:59:59+00:00  1433942885716615173
# 1      2021-09-03 23:59:19+00:00  1433942716996485123
# 2      2021-09-03 23:58:58+00:00  1433942626944884738
# 3      2021-09-03 23:58:16+00:00  1433942451937501191
# 4      2021-09-03 23:57:08+00:00  1433942167152697346
# ...                          ...                  ...
# 65529  2021-08-26 14:54:38+00:00  1430906539494154244
# 65530  2021-08-26 14:47:45+00:00  1430904806038642696
# 65531  2021-08-26 13:28:18+00:00  1430884811292487682
# 65532  2021-08-26 13:01:08+00:00  1430877976632061961
# 65533  2021-08-26 12:30:08+00:00  1430870173876211714
#
#                                                     Text         Username  \
# 0      @POTUS flying entourage over W Jeff Parish, su...  AnthonyMcAuley2
# 1      Air operations underway @ Grand Isle, LA #Hurr...    ClarkCountyNV
# 2      I signed up to volunteer by helping man the co...       dikayodata
# ...

# %% [markdown]
# ## Split Date and Time

# %%
twitter_df['Dates'] = pd.to_datetime(twitter_df['Datetime']).dt.date
twitter_df['Time'] = pd.to_datetime(twitter_df['Datetime']).dt.time
twitter_df
# Out:
#                         Datetime             Tweet Id  \
# 0      2021-09-03 23:59:59+00:00  1433942885716615173
# 1      2021-09-03 23:59:19+00:00  1433942716996485123
# 2      2021-09-03 23:58:58+00:00  1433942626944884738
# 3      2021-09-03 23:58:16+00:00  1433942451937501191
# 4      2021-09-03 23:57:08+00:00  1433942167152697346
# ...                          ...                  ...
# 65529  2021-08-26 14:54:38+00:00  1430906539494154244
# 65530  2021-08-26 14:47:45+00:00  1430904806038642696
# 65531  2021-08-26 13:28:18+00:00  1430884811292487682
# 65532  2021-08-26 13:01:08+00:00  1430877976632061961
# 65533  2021-08-26 12:30:08+00:00  1430870173876211714
#
#                                                     Text         Username  \
# 0      @POTUS flying entourage over W Jeff Parish, su...  AnthonyMcAuley2
# 1      Air operations underway @ Grand Isle, LA #Hurr...    ClarkCountyNV
# 2      I signed up to volunteer by helping man the co...       dikayodata
# ...

# %% [markdown]
# ## Remove URL, mentions, hashtags, numbers and foreign languages from Tweets

# %%
twitter_df['CleanText'] = twitter_df['Text'].replace(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', regex=True)
twitter_df['CleanText'] = twitter_df['CleanText'].replace(r'@[A-Za-z0-9_]+', '', regex=True)
twitter_df['CleanText'] = twitter_df['CleanText'].replace(r'#[A-Za-z0-9_]+', '', regex=True)
twitter_df = twitter_df[twitter_df.CleanText.map(lambda x: x.isascii())]

# %%
twitter_df.to_csv("./data/cleaned_twitter.csv")
